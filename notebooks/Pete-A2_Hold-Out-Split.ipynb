# %% [markdown]
# # Create a hold-out set for final testing
#
# Author: Pete King
#
# This notebook creates a separate testing dataset to hold in reserve for a final evaluation of our selected model's ability to generalize to unseen data.

# %%
from pathlib import Path
import re

import pandas as pd

from helpers import data_prep as dp

DATA_DIR = Path.cwd().parent / 'data'
DATA_FILE = DATA_DIR / 'raw_data_prediction_dataset.csv'

# %%
# Select the data file and start date for the testing set
# ----------------------------------------------------------------------------
# We want to rigorously test our final model against a period of dynamic
# real-world volatility.  For example, beginning in October 2024 would capture
# an initial period of relatively low volatility, followed by the highly 
# volatility period after Trump announced reciprocal tarrifs in April 2025.
# ----------------------------------------------------------------------------
TESTING_START_DATE = '2024-10-01'
# Select buffer size between validation/test and training sets
# We calculate target variables using 63 days of "future" historical data
# A buffer of one quarter (63 business days) guards against data leakage
BUFFER_SIZE = 63

# %%
# Import feature dataset with labels
df = pd.read_csv(DATA_FILE)
df
# Out:
#              date  nominal_GDP   real_GDP  debt_to_GDP  debt_interest  \
# 0      1927-12-30          NaN        NaN          NaN            NaN
# 1      1928-01-03          NaN        NaN          NaN            NaN
# 2      1928-01-04          NaN        NaN          NaN            NaN
# 3      1928-01-05          NaN        NaN          NaN            NaN
# 4      1928-01-06          NaN        NaN          NaN            NaN
# ...           ...          ...        ...          ...            ...
# 25028  2026-04-09    31422.526  24055.749    122.56815       1227.495
# 25029  2026-04-10    31422.526  24055.749    122.56815       1227.495
# 25030  2026-04-13    31422.526  24055.749    122.56815       1227.495
# 25031  2026-04-14          NaN        NaN          NaN            NaN
# 25032  2026-04-15          NaN        NaN          NaN            NaN
#
#        consumer_price_index  core_PCI  personal_consumption_expenditure  \
# 0                       NaN       NaN                               NaN
# 1                       NaN       NaN                               NaN
# 2                       NaN       NaN                               NaN
# 3                       NaN       NaN                               NaN
# 4                       NaN       NaN                               NaN
# ...                     ...       ...                               ...
# 25028               330.293   334.165                           129.449
# 25029               330.293   334.165                           129.449
# 25030               330.293   334.165                           129.449
# 25031                   NaN       NaN                               NaN
# 25032                   NaN       NaN                               NaN
#
#        core_PCE  producer_price_index  ...  TLT_logreturn_target  \
# 0           NaN                   NaN  ...                   NaN
# 1           NaN                   NaN  ...                   NaN
# 2           NaN                   NaN  ...                   NaN
# 3           NaN                   NaN  ...                   NaN
# 4           NaN                   NaN  ...                   NaN
# ...         ...                   ...  ...                   ...
# 25028   128.859               154.006  ...                   NaN
# 25029   128.859               154.006  ...                   NaN
# 25030   128.859               154.006  ...                   NaN
# 25031       NaN                   NaN  ...                   NaN
# 25032       NaN                   NaN  ...                   NaN
#
#        TLT_volatility_target  LQD_logreturn_target  LQD_volatility_target  \
# 0                        NaN                   NaN                    NaN
# 1                        NaN                   NaN                    NaN
# 2                        NaN                   NaN                    NaN
# 3                        NaN                   NaN                    NaN
# 4                        NaN                   NaN                    NaN
# ...                      ...                   ...                    ...
# 25028                    NaN                   NaN                    NaN
# 25029                    NaN                   NaN                    NaN
# 25030                    NaN                   NaN                    NaN
# 25031                    NaN                   NaN                    NaN
# 25032                    NaN                   NaN                    NaN
#
#        HYG_logreturn_target  HYG_volatility_target  TIP_logreturn_target  \
# 0                       NaN                    NaN                   NaN
# 1                       NaN                    NaN                   NaN
# 2                       NaN                    NaN                   NaN
# 3                       NaN                    NaN                   NaN
# 4                       NaN                    NaN                   NaN
# ...                     ...                    ...                   ...
# 25028                   NaN                    NaN                   NaN
# 25029                   NaN                    NaN                   NaN
# 25030                   NaN                    NaN                   NaN
# 25031                   NaN                    NaN                   NaN
# 25032                   NaN                    NaN                   NaN
#
#        TIP_volatility_target  GLD_logreturn_target  GLD_volatility_target
# 0                        NaN                   NaN                    NaN
# 1                        NaN                   NaN                    NaN
# 2                        NaN                   NaN                    NaN
# 3                        NaN                   NaN                    NaN
# 4                        NaN                   NaN                    NaN
# ...                      ...                   ...                    ...
# 25028                    NaN                   NaN                    NaN
# 25029                    NaN                   NaN                    NaN
# 25030                    NaN                   NaN                    NaN
# 25031                    NaN                   NaN                    NaN
# 25032                    NaN                   NaN                    NaN
#
# [25033 rows x 93 columns]

# %% [markdown]
# Let's look at the earliest starting dates for each of our column labels to see how far back our labels go for each ETF.

# %%
label_tag = '_volatility_target'
# Use a regular expression to parse the ticker symbol from the column name
p = re.compile(label_tag)
start_dates = {}
for column_name in df.columns:
    if label_tag in column_name:
        ticker = p.split(column_name)[0]
        start_dates[ticker] = (
            df[['date', column_name]].dropna().date.iloc[0]
        )
sorted([(k, v) for k, v in start_dates.items()], key=lambda pair: pair[1])
# Out:
# [('XLF', '1998-12-22'),
#  ('XLK', '1998-12-22'),
#  ('XLU', '1998-12-22'),
#  ('XLV', '1998-12-22'),
#  ('XLE', '1998-12-22'),
#  ('XLI', '1998-12-22'),
#  ('XLB', '1998-12-22'),
#  ('XLP', '1998-12-22'),
#  ('XLY', '1998-12-22'),
#  ('IEF', '2002-07-30'),
#  ('TLT', '2002-07-30'),
#  ('LQD', '2002-07-30'),
#  ('TIP', '2003-12-05'),
#  ('GLD', '2004-11-18'),
#  ('HYG', '2007-04-11'),
#  ('BIL', '2007-05-30'),
#  ('XLRE', '2015-10-08')]

# %%
print(f'The XLRE (Real Estate) series only goes back to {start_dates['XLRE']}')
# Out:
# The XLRE (Real Estate) series only goes back to 2015-10-08

# %% [markdown]
# For the Vector AutoRegressive Integrated Moving Average (VARIMA) and the multivariate Long Short-Term Memory (LSTM) models, we intend to use fluctuations in the price of all labeled ETF price time series as features.  However, we've observed that a few of these time series have significantly later start dates than the others.  For example, if we drop the 'XLRE' ETF (Real Estate) from the dataset, we'll free up 8 years worth of training data for the rest of the ETFs.
#
# Going forward, we plan to test three variations of the data:
#
#  - Including all raw data from roughly 2015 (start of XLRE data)
#  - Dropping XLRE (Real Estate) to make data as early as 2007 available
#  - Dropping HYG and BIL to make data as early as 2004 available

# %%
train_val_df, test_df = dp.time_series_split(
    df, TESTING_START_DATE, BUFFER_SIZE
)
train_val_df
# Out:
#              date  nominal_GDP   real_GDP  debt_to_GDP  debt_interest  \
# 0      1927-12-30          NaN        NaN          NaN            NaN
# 1      1928-01-03          NaN        NaN          NaN            NaN
# 2      1928-01-04          NaN        NaN          NaN            NaN
# 3      1928-01-05          NaN        NaN          NaN            NaN
# 4      1928-01-06          NaN        NaN          NaN            NaN
# ...           ...          ...        ...          ...            ...
# 24569  2024-06-27    29147.044  23286.508    119.50314       1103.565
# 24570  2024-06-28    29147.044  23286.508    119.50314       1103.565
# 24571  2024-07-01    29511.664  23478.570    120.17172       1146.182
# 24572  2024-07-02    29511.664  23478.570    120.17172       1146.182
# 24573  2024-07-03    29511.664  23478.570    120.17172       1146.182
#
#        consumer_price_index  core_PCI  personal_consumption_expenditure  \
# 0                       NaN       NaN                               NaN
# 1                       NaN       NaN                               NaN
# 2                       NaN       NaN                               NaN
# 3                       NaN       NaN                               NaN
# 4                       NaN       NaN                               NaN
# ...                     ...       ...                               ...
# 24569               313.044    318.39                           123.539
# 24570               313.044    318.39                           123.539
# 24571               313.569    318.94                           123.736
# 24572               313.569    318.94                           123.736
# 24573               313.569    318.94                           123.736
#
#        core_PCE  producer_price_index  ...  TLT_logreturn_target  \
# 0           NaN                   NaN  ...                   NaN
# 1           NaN                   NaN  ...                   NaN
# 2           NaN                   NaN  ...                   NaN
# 3           NaN                   NaN  ...                   NaN
# 4           NaN                   NaN  ...                   NaN
# ...         ...                   ...  ...                   ...
# 24569   122.677               144.869  ...              0.228628
# 24570   122.677               144.869  ...              0.324500
# 24571   122.911               144.922  ...              0.375021
# 24572   122.911               144.922  ...              0.372775
# 24573   122.911               144.922  ...              0.286733
#
#        TLT_volatility_target  LQD_logreturn_target  LQD_volatility_target  \
# 0                        NaN                   NaN                    NaN
# 1                        NaN                   NaN                    NaN
# 2                        NaN                   NaN                    NaN
# 3                        NaN                   NaN                    NaN
# 4                        NaN                   NaN                    NaN
# ...                      ...                   ...                    ...
# 24569               0.143677              0.224334               0.062757
# 24570               0.138221              0.265942               0.061263
# 24571               0.133504              0.279870               0.060026
# 24572               0.133402              0.273496               0.059539
# 24573               0.132755              0.235163               0.058503
#
#        HYG_logreturn_target  HYG_volatility_target  TIP_logreturn_target  \
# 0                       NaN                    NaN                   NaN
# 1                       NaN                    NaN                   NaN
# 2                       NaN                    NaN                   NaN
# 3                       NaN                    NaN                   NaN
# 4                       NaN                    NaN                   NaN
# ...                     ...                    ...                   ...
# 24569              0.204916               0.037339              0.140210
# 24570              0.224723               0.036885              0.162335
# 24571              0.222517               0.036968              0.175744
# 24572              0.209580               0.036876              0.181298
# 24573              0.196068               0.036498              0.161884
#
#        TIP_volatility_target  GLD_logreturn_target  GLD_volatility_target
# 0                        NaN                   NaN                    NaN
# 1                        NaN                   NaN                    NaN
# 2                        NaN                   NaN                    NaN
# 3                        NaN                   NaN                    NaN
# 4                        NaN                   NaN                    NaN
# ...                      ...                   ...                    ...
# 24569               0.040557              0.554863               0.144959
# 24570               0.040043              0.522621               0.146326
# 24571               0.039016              0.480090               0.147709
# 24572               0.039286              0.522023               0.148631
# 24573               0.038860              0.477997               0.147506
#
# [24574 rows x 93 columns]

# %%
test_df
# Out:
#              date  nominal_GDP   real_GDP  debt_to_GDP  debt_interest  \
# 24637  2024-10-01    29825.182  23586.542    121.43633       1155.616
# 24638  2024-10-02    29825.182  23586.542    121.43633       1155.616
# 24639  2024-10-03    29825.182  23586.542    121.43633       1155.616
# 24640  2024-10-04    29825.182  23586.542    121.43633       1155.616
# 24641  2024-10-07    29825.182  23586.542    121.43633       1155.616
# ...           ...          ...        ...          ...            ...
# 25028  2026-04-09    31422.526  24055.749    122.56815       1227.495
# 25029  2026-04-10    31422.526  24055.749    122.56815       1227.495
# 25030  2026-04-13    31422.526  24055.749    122.56815       1227.495
# 25031  2026-04-14          NaN        NaN          NaN            NaN
# 25032  2026-04-15          NaN        NaN          NaN            NaN
#
#        consumer_price_index  core_PCI  personal_consumption_expenditure  \
# 24637               315.631   321.731                           124.494
# 24638               315.631   321.731                           124.494
# 24639               315.631   321.731                           124.494
# 24640               315.631   321.731                           124.494
# 24641               315.631   321.731                           124.494
# ...                     ...       ...                               ...
# 25028               330.293   334.165                           129.449
# 25029               330.293   334.165                           129.449
# 25030               330.293   334.165                           129.449
# 25031                   NaN       NaN                               NaN
# 25032                   NaN       NaN                               NaN
#
#        core_PCE  producer_price_index  ...  TLT_logreturn_target  \
# 24637   123.832               146.294  ...             -0.438186
# 24638   123.832               146.294  ...             -0.393358
# 24639   123.832               146.294  ...             -0.368308
# 24640   123.832               146.294  ...             -0.336711
# 24641   123.832               146.294  ...             -0.351819
# ...         ...                   ...  ...                   ...
# 25028   128.859               154.006  ...                   NaN
# 25029   128.859               154.006  ...                   NaN
# 25030   128.859               154.006  ...                   NaN
# 25031       NaN                   NaN  ...                   NaN
# 25032       NaN                   NaN  ...                   NaN
#
#        TLT_volatility_target  LQD_logreturn_target  LQD_volatility_target  \
# 24637               0.145855             -0.185907               0.075138
# 24638               0.145477             -0.176682               0.075096
# 24639               0.144630             -0.160094               0.074250
# 24640               0.143062             -0.148419               0.073707
# 24641               0.143927             -0.146398               0.073588
# ...                      ...                   ...                    ...
# 25028                    NaN                   NaN                    NaN
# 25029                    NaN                   NaN                    NaN
# 25030                    NaN                   NaN                    NaN
# 25031                    NaN                   NaN                    NaN
# 25032                    NaN                   NaN                    NaN
#
#        HYG_logreturn_target  HYG_volatility_target  TIP_logreturn_target  \
# 24637             -0.002813               0.041414             -0.136964
# 24638              0.006336               0.041697             -0.127348
# 24639              0.021946               0.041511             -0.118570
# 24640              0.033553               0.041571             -0.091240
# 24641              0.037504               0.041190             -0.093240
# ...                     ...                    ...                   ...
# 25028                   NaN                    NaN                   NaN
# 25029                   NaN                    NaN                   NaN
# 25030                   NaN                    NaN                   NaN
# 25031                   NaN                    NaN                   NaN
# 25032                   NaN                    NaN                   NaN
#
#        TIP_volatility_target  GLD_logreturn_target  GLD_volatility_target
# 24637               0.041522             -0.057080               0.161541
# 24638               0.041716             -0.003910               0.163856
# 24639               0.041140             -0.032721               0.164609
# 24640               0.039063             -0.029661               0.164580
# 24641               0.039114              0.006384               0.164838
# ...                      ...                   ...                    ...
# 25028                    NaN                   NaN                    NaN
# 25029                    NaN                   NaN                    NaN
# 25030                    NaN                   NaN                    NaN
# 25031                    NaN                   NaN                    NaN
# 25032                    NaN                   NaN                    NaN
#
# [396 rows x 93 columns]

# %% [markdown]
# The gap between the training and testing sets guards against data leakage.

# %%
# Save segmented datasets for further analysis; drop the index
train_val_df.to_csv(DATA_DIR / 'train_val_data.csv', index=False)
test_df.to_csv(DATA_DIR / 'test_data.csv', index=False)
